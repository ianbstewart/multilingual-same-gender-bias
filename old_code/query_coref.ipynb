# %% [markdown]
# ## Query coreference
# We have previously determined that Google Translate has trouble understanding same-gender (SG) relationships in French, Italian, Spanish. Let's see if that bias persists in coreference resolution in the following format:
#
# - `Juan and Carla talked about her girlfriend`
# - `Juan y Carla hablaban sobre su novia`

# %%
## does spacy work??
import spacy
nlp = spacy.load('es_core_news_sm')
test_sent = 'Juan y Carla hablaban sobre su novia'
doc = nlp(test_sent)
sents = list(doc.sents)
print(dir(sents[0]))
# Out:
# ['_', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_fix_dep_copy', '_vector', '_vector_norm', 'as_doc', 'char_span', 'conjuncts', 'doc', 'end', 'end_char', 'ent_id', 'ent_id_', 'ents', 'get_extension', 'get_lca_matrix', 'has_extension', 'has_vector', 'kb_id', 'kb_id_', 'label', 'label_', 'lefts', 'lemma_', 'n_lefts', 'n_rights', 'noun_chunks', 'orth_', 'remove_extension', 'rights', 'root', 'sent', 'sentiment', 'set_extension', 'similarity', 'start', 'start_char', 'subtree', 'tensor', 'text', 'text_with_ws', 'to_array', 'vector', 'vector_norm', 'vocab']

# %%
print(sents[0].noun_chunks)
# Out:
# [Juan, Carla, su novia]

# %% [markdown]
# Next step: try `CoreNLP` via `stanza`, which means setting up a separate server...fun.

# %%
from stanza.server import CoreNLPClient
import os
corenlp_dir = '/Users/istewart/Documents/Research/CoreNLP/stanford-corenlp-4.2.2'
os.environ['CORENLP_HOME'] = corenlp_dir
# Out:
# 2021-08-21 16:34:19 INFO: Writing properties to tmp file: corenlp_server-bde5ddb2d4354b85.props

# %%
test_sent = 'Juan y la Señora Carla hablaban sobre su novia, y ella no sabía qué hacer'
with CoreNLPClient(annotators=['tokenize','ssplit', 'pos', 'lemma', 'ner', 'coref'],  memory='2G', endpoint='http://localhost:9000', be_quiet=True, properties='spanish') as client:
    document = client.annotate(test_sent)
# Out:
# 2021-08-21 16:47:03 INFO: Using CoreNLP default properties for: spanish.  Make sure to have spanish models jar (available for download here: https://stanfordnlp.github.io/CoreNLP/) in CLASSPATH
# 2021-08-21 16:47:03 INFO: Starting server with command: java -Xmx2G -cp /Users/istewart/Documents/Research/CoreNLP/stanford-corenlp-4.2.2/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties spanish -annotators tokenize,ssplit,pos,lemma,ner,coref -preload -outputFormat serialized

# %%
display(document)
# Out:
# text: "Juan y la Se\303\261ora Carla hablaban sobre su novia, y ella no sab\303\255a qu\303\251 hacer"
# sentence {
#   token {
#     word: "Juan"
#     pos: "PROPN"
#     value: "Juan"
#     before: ""
#     after: " "
#     originalText: "Juan"
#     ner: "PERSON"
#     lemma: "juan"
#     beginChar: 0
#     endChar: 4
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 0
#     tokenEndIndex: 1
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "PERSON"
#     fineGrainedNER: "PERSON"
#     corefMentionIndex: 0
#     entityMentionIndex: 0
#     nerLabelProbs: "PERSON=0.9756629291762796"
#   }
#   token {
#     word: "y"
#     pos: "CCONJ"
#     value: "y"
#     before: " "
#     after: " "
#     originalText: "y"
#     ner: "O"
#     lemma: "y"
#     beginChar: 5
#     endChar: 6
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 1
#     tokenEndIndex: 2
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9935061997903432"
#   }
#   token {
#     word: "la"
#     pos: "DET"
#     value: "la"
#     before: " "
#     after: " "
#     originalText: "la"
#     ner: "O"
#     lemma: "la"
#     beginChar: 7
#     endChar: 9
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 2
#     tokenEndIndex: 3
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9922043097482508"
#   }
#   token {
#     word: "Se\303\261ora"
#     pos: "PROPN"
#     value: "Se\303\261ora"
#     before: " "
#     after: " "
#     originalText: "Se\303\261ora"
#     ner: "O"
#     lemma: "se\303\261ora"
#     beginChar: 10
#     endChar: 16
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 3
#     tokenEndIndex: 4
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.6452601828272706"
#   }
#   token {
#     word: "Carla"
#     pos: "PROPN"
#     value: "Carla"
#     before: " "
#     after: " "
#     originalText: "Carla"
#     ner: "PERSON"
#     lemma: "carla"
#     beginChar: 17
#     endChar: 22
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 4
#     tokenEndIndex: 5
#     hasXmlContext: false
#     isNewline: false
#     parent: "vb_pn_attached"
#     coarseNER: "PERSON"
#     fineGrainedNER: "PERSON"
#     corefMentionIndex: 1
#     entityMentionIndex: 1
#     nerLabelProbs: "PERSON=0.9526049001812095"
#   }
#   token {
#     word: "hablaban"
#     pos: "VERB"
#     value: "hablaban"
#     before: " "
#     after: " "
#     originalText: "hablaban"
#     ner: "O"
#     lemma: "hablaban"
#     beginChar: 23
#     endChar: 31
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 5
#     tokenEndIndex: 6
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9918794458455595"
#   }
#   token {
#     word: "sobre"
#     pos: "ADP"
#     value: "sobre"
#     before: " "
#     after: " "
#     originalText: "sobre"
#     ner: "O"
#     lemma: "sobre"
#     beginChar: 32
#     endChar: 37
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 6
#     tokenEndIndex: 7
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     corefMentionIndex: 2
#     nerLabelProbs: "O=0.9999582665025711"
#   }
#   token {
#     word: "su"
#     pos: "DET"
#     value: "su"
#     before: " "
#     after: " "
#     originalText: "su"
#     ner: "O"
#     lemma: "su"
#     beginChar: 38
#     endChar: 40
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 7
#     tokenEndIndex: 8
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     corefMentionIndex: 2
#     nerLabelProbs: "O=0.999936802733481"
#   }
#   token {
#     word: "novia"
#     pos: "NOUN"
#     value: "novia"
#     before: " "
#     after: ""
#     originalText: "novia"
#     ner: "O"
#     lemma: "novia"
#     beginChar: 41
#     endChar: 46
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 8
#     tokenEndIndex: 9
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     corefMentionIndex: 2
#     nerLabelProbs: "O=0.9993439670975844"
#   }
#   token {
#     word: ","
#     pos: "PUNCT"
#     value: ","
#     before: ""
#     after: " "
#     originalText: ","
#     ner: "O"
#     lemma: ","
#     beginChar: 46
#     endChar: 47
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 9
#     tokenEndIndex: 10
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9999927113664476"
#   }
#   token {
#     word: "y"
#     pos: "CCONJ"
#     value: "y"
#     before: " "
#     after: " "
#     originalText: "y"
#     ner: "O"
#     lemma: "y"
#     beginChar: 48
#     endChar: 49
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 10
#     tokenEndIndex: 11
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9999921001215284"
#   }
#   token {
#     word: "ella"
#     pos: "PRON"
#     value: "ella"
#     before: " "
#     after: " "
#     originalText: "ella"
#     ner: "O"
#     lemma: "ella"
#     beginChar: 50
#     endChar: 54
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 11
#     tokenEndIndex: 12
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9997370588898574"
#   }
#   token {
#     word: "no"
#     pos: "ADV"
#     value: "no"
#     before: " "
#     after: " "
#     originalText: "no"
#     ner: "O"
#     lemma: "no"
#     beginChar: 55
#     endChar: 57
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 12
#     tokenEndIndex: 13
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9999971745902041"
#   }
#   token {
#     word: "sab\303\255a"
#     pos: "VERB"
#     value: "sab\303\255a"
#     before: " "
#     after: " "
#     originalText: "sab\303\255a"
#     ner: "O"
#     lemma: "sab\303\255a"
#     beginChar: 58
#     endChar: 63
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 13
#     tokenEndIndex: 14
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.9999892423700316"
#   }
#   token {
#     word: "qu\303\251"
#     pos: "PRON"
#     value: "qu\303\251"
#     before: " "
#     after: " "
#     originalText: "qu\303\251"
#     ner: "O"
#     lemma: "qu\303\251"
#     beginChar: 64
#     endChar: 67
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 14
#     tokenEndIndex: 15
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.999968599255464"
#   }
#   token {
#     word: "hacer"
#     pos: "VERB"
#     value: "hacer"
#     before: " "
#     after: ""
#     originalText: "hacer"
#     ner: "O"
#     lemma: "hacer"
#     beginChar: 68
#     endChar: 73
#     utterance: 0
#     speaker: "PER0"
#     tokenBeginIndex: 15
#     tokenEndIndex: 16
#     hasXmlContext: false
#     isNewline: false
#     coarseNER: "O"
#     fineGrainedNER: "O"
#     nerLabelProbs: "O=0.998802184116629"
#   }
#   tokenOffsetBegin: 0
#   tokenOffsetEnd: 16
#   sentenceIndex: 0
#   characterOffsetBegin: 0
#   characterOffsetEnd: 73
#   basicDependencies {
#     node {
#       sentenceIndex: 0
#       index: 1
#     }
#     node {
#       sentenceIndex: 0
#       index: 2
#     }
#     node {
#       sentenceIndex: 0
#       index: 3
#     }
#     node {
#       sentenceIndex: 0
#       index: 4
#     }
#     node {
#       sentenceIndex: 0
#       index: 5
#     }
#     node {
#       sentenceIndex: 0
#       index: 6
#     }
#     node {
#       sentenceIndex: 0
#       index: 7
#     }
#     node {
#       sentenceIndex: 0
#       index: 8
#     }
#     node {
#       sentenceIndex: 0
#       index: 9
#     }
#     node {
#       sentenceIndex: 0
#       index: 10
#     }
#     node {
#       sentenceIndex: 0
#       index: 11
#     }
#     node {
#       sentenceIndex: 0
#       index: 12
#     }
#     node {
#       sentenceIndex: 0
#       index: 13
#     }
#     node {
#       sentenceIndex: 0
#       index: 14
#     }
#     node {
#       sentenceIndex: 0
#       index: 15
#     }
#     node {
#       sentenceIndex: 0
#       index: 16
#     }
#     edge {
#       source: 1
#       target: 4
#       dep: "conj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 2
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 3
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 5
#       dep: "flat"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 1
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 9
#       dep: "obl"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 14
#       dep: "conj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 9
#       target: 7
#       dep: "case"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 9
#       target: 8
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 16
#       dep: "xcomp"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 10
#       dep: "punct"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 11
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 12
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 13
#       dep: "advmod"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 16
#       target: 15
#       dep: "obj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     root: 6
#   }
#   collapsedDependencies {
#     node {
#       sentenceIndex: 0
#       index: 1
#     }
#     node {
#       sentenceIndex: 0
#       index: 2
#     }
#     node {
#       sentenceIndex: 0
#       index: 3
#     }
#     node {
#       sentenceIndex: 0
#       index: 4
#     }
#     node {
#       sentenceIndex: 0
#       index: 5
#     }
#     node {
#       sentenceIndex: 0
#       index: 6
#     }
#     node {
#       sentenceIndex: 0
#       index: 7
#     }
#     node {
#       sentenceIndex: 0
#       index: 8
#     }
#     node {
#       sentenceIndex: 0
#       index: 9
#     }
#     node {
#       sentenceIndex: 0
#       index: 10
#     }
#     node {
#       sentenceIndex: 0
#       index: 11
#     }
#     node {
#       sentenceIndex: 0
#       index: 12
#     }
#     node {
#       sentenceIndex: 0
#       index: 13
#     }
#     node {
#       sentenceIndex: 0
#       index: 14
#     }
#     node {
#       sentenceIndex: 0
#       index: 15
#     }
#     node {
#       sentenceIndex: 0
#       index: 16
#     }
#     edge {
#       source: 1
#       target: 4
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 4
#       target: 2
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 3
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 5
#       dep: "flat"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 1
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 9
#       dep: "obl"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 14
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 9
#       target: 7
#       dep: "case"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 9
#       target: 8
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 16
#       dep: "xcomp"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 10
#       dep: "punct"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 11
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 12
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 13
#       dep: "advmod"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 16
#       target: 15
#       dep: "obj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     root: 6
#   }
#   collapsedCCProcessedDependencies {
#     node {
#       sentenceIndex: 0
#       index: 1
#     }
#     node {
#       sentenceIndex: 0
#       index: 2
#     }
#     node {
#       sentenceIndex: 0
#       index: 3
#     }
#     node {
#       sentenceIndex: 0
#       index: 4
#     }
#     node {
#       sentenceIndex: 0
#       index: 5
#     }
#     node {
#       sentenceIndex: 0
#       index: 6
#     }
#     node {
#       sentenceIndex: 0
#       index: 7
#     }
#     node {
#       sentenceIndex: 0
#       index: 8
#     }
#     node {
#       sentenceIndex: 0
#       index: 9
#     }
#     node {
#       sentenceIndex: 0
#       index: 10
#     }
#     node {
#       sentenceIndex: 0
#       index: 11
#     }
#     node {
#       sentenceIndex: 0
#       index: 12
#     }
#     node {
#       sentenceIndex: 0
#       index: 13
#     }
#     node {
#       sentenceIndex: 0
#       index: 14
#     }
#     node {
#       sentenceIndex: 0
#       index: 15
#     }
#     node {
#       sentenceIndex: 0
#       index: 16
#     }
#     edge {
#       source: 1
#       target: 4
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 4
#       target: 2
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 3
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 5
#       dep: "flat"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 1
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 4
#       dep: "nsubj"
#       isExtra: true
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 9
#       dep: "obl"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 14
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 9
#       target: 7
#       dep: "case"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 9
#       target: 8
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 16
#       dep: "xcomp"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 10
#       dep: "punct"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 11
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 12
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 13
#       dep: "advmod"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 16
#       target: 15
#       dep: "obj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     root: 6
#   }
#   paragraph: 1
#   enhancedDependencies {
#     node {
#       sentenceIndex: 0
#       index: 1
#     }
#     node {
#       sentenceIndex: 0
#       index: 2
#     }
#     node {
#       sentenceIndex: 0
#       index: 3
#     }
#     node {
#       sentenceIndex: 0
#       index: 4
#     }
#     node {
#       sentenceIndex: 0
#       index: 5
#     }
#     node {
#       sentenceIndex: 0
#       index: 6
#     }
#     node {
#       sentenceIndex: 0
#       index: 7
#     }
#     node {
#       sentenceIndex: 0
#       index: 8
#     }
#     node {
#       sentenceIndex: 0
#       index: 9
#     }
#     node {
#       sentenceIndex: 0
#       index: 10
#     }
#     node {
#       sentenceIndex: 0
#       index: 11
#     }
#     node {
#       sentenceIndex: 0
#       index: 12
#     }
#     node {
#       sentenceIndex: 0
#       index: 13
#     }
#     node {
#       sentenceIndex: 0
#       index: 14
#     }
#     node {
#       sentenceIndex: 0
#       index: 15
#     }
#     node {
#       sentenceIndex: 0
#       index: 16
#     }
#     edge {
#       source: 1
#       target: 4
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 4
#       target: 2
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 3
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 5
#       dep: "flat"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 1
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 4
#       dep: "nsubj"
#       isExtra: true
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 9
#       dep: "obl"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 14
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 9
#       target: 7
#       dep: "case"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 9
#       target: 8
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 16
#       dep: "xcomp"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 10
#       dep: "punct"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 11
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 12
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 13
#       dep: "advmod"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 16
#       target: 15
#       dep: "obj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     root: 6
#   }
#   enhancedPlusPlusDependencies {
#     node {
#       sentenceIndex: 0
#       index: 1
#     }
#     node {
#       sentenceIndex: 0
#       index: 2
#     }
#     node {
#       sentenceIndex: 0
#       index: 3
#     }
#     node {
#       sentenceIndex: 0
#       index: 4
#     }
#     node {
#       sentenceIndex: 0
#       index: 5
#     }
#     node {
#       sentenceIndex: 0
#       index: 6
#     }
#     node {
#       sentenceIndex: 0
#       index: 7
#     }
#     node {
#       sentenceIndex: 0
#       index: 8
#     }
#     node {
#       sentenceIndex: 0
#       index: 9
#     }
#     node {
#       sentenceIndex: 0
#       index: 10
#     }
#     node {
#       sentenceIndex: 0
#       index: 11
#     }
#     node {
#       sentenceIndex: 0
#       index: 12
#     }
#     node {
#       sentenceIndex: 0
#       index: 13
#     }
#     node {
#       sentenceIndex: 0
#       index: 14
#     }
#     node {
#       sentenceIndex: 0
#       index: 15
#     }
#     node {
#       sentenceIndex: 0
#       index: 16
#     }
#     edge {
#       source: 1
#       target: 4
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 4
#       target: 2
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 3
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 4
#       target: 5
#       dep: "flat"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 1
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 4
#       dep: "nsubj"
#       isExtra: true
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 9
#       dep: "obl"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 6
#       target: 14
#       dep: "conj:y"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: UniversalEnglish
#     }
#     edge {
#       source: 9
#       target: 7
#       dep: "case"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 9
#       target: 8
#       dep: "det"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 16
#       dep: "xcomp"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 10
#       dep: "punct"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 11
#       dep: "cc"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 12
#       dep: "nsubj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 14
#       target: 13
#       dep: "advmod"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     edge {
#       source: 16
#       target: 15
#       dep: "obj"
#       isExtra: false
#       sourceCopy: 0
#       targetCopy: 0
#       language: Spanish
#     }
#     root: 6
#   }
#   hasRelationAnnotations: false
#   hasNumerizedTokensAnnotation: false
#   mentions {
#     sentenceIndex: 0
#     tokenStartInSentenceInclusive: 0
#     tokenEndInSentenceExclusive: 1
#     ner: "PERSON"
#     entityType: "PERSON"
#     entityMentionIndex: 0
#     canonicalEntityMentionIndex: 0
#     entityMentionText: "Juan"
#   }
#   mentions {
#     sentenceIndex: 0
#     tokenStartInSentenceInclusive: 4
#     tokenEndInSentenceExclusive: 5
#     ner: "PERSON"
#     entityType: "PERSON"
#     entityMentionIndex: 1
#     canonicalEntityMentionIndex: 1
#     entityMentionText: "Carla"
#   }
#   mentionsForCoref {
#     mentionID: 0
#     mentionType: "PROPER"
#     number: "SINGULAR"
#     gender: "MALE"
#     animacy: "ANIMATE"
#     person: "UNKNOWN"
#     startIndex: 0
#     endIndex: 1
#     headIndex: 0
#     headString: "juan"
#     nerString: "PERSON"
#     originalRef: -1
#     goldCorefClusterID: -1
#     corefClusterID: 0
#     mentionNum: 0
#     sentNum: 0
#     utter: 0
#     paragraph: 1
#     isSubject: true
#     isDirectObject: false
#     isIndirectObject: false
#     isPrepositionObject: false
#     hasTwin: false
#     generic: false
#     isSingleton: false
#     hasBasicDependency: true
#     hasEnhancedDepenedncy: true
#     hasContextParseTree: false
#     headIndexedWord {
#       sentenceNum: -1
#       tokenIndex: 0
#       copyCount: 0
#     }
#     dependingVerb {
#       sentenceNum: -1
#       tokenIndex: 5
#       copyCount: 0
#     }
#     headWord {
#       sentenceNum: -1
#       tokenIndex: 0
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 0
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 1
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 2
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 3
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 4
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 5
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 6
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 7
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 8
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 9
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 10
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 11
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 12
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 13
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 14
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 15
#     }
#     originalSpan {
#       sentenceNum: -1
#       tokenIndex: 0
#     }
#   }
#   mentionsForCoref {
#     mentionID: 1
#     mentionType: "PROPER"
#     number: "SINGULAR"
#     gender: "FEMALE"
#     animacy: "ANIMATE"
#     person: "UNKNOWN"
#     startIndex: 4
#     endIndex: 5
#     headIndex: 4
#     headString: "carla"
#     nerString: "PERSON"
#     originalRef: -1
#     goldCorefClusterID: -1
#     corefClusterID: 1
#     mentionNum: 1
#     sentNum: 0
#     utter: 0
#     paragraph: 1
#     isSubject: false
#     isDirectObject: false
#     isIndirectObject: false
#     isPrepositionObject: false
#     hasTwin: false
#     generic: false
#     isSingleton: false
#     hasBasicDependency: true
#     hasEnhancedDepenedncy: true
#     hasContextParseTree: false
#     headIndexedWord {
#       sentenceNum: -1
#       tokenIndex: 4
#       copyCount: 0
#     }
#     dependingVerb {
#       sentenceNum: -1
#       tokenIndex: 5
#       copyCount: 0
#     }
#     headWord {
#       sentenceNum: -1
#       tokenIndex: 4
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 0
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 1
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 2
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 3
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 4
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 5
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 6
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 7
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 8
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 9
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 10
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 11
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 12
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 13
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 14
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 15
#     }
#     originalSpan {
#       sentenceNum: -1
#       tokenIndex: 4
#     }
#   }
#   mentionsForCoref {
#     mentionID: 2
#     mentionType: "NOMINAL"
#     number: "SINGULAR"
#     gender: "MALE"
#     animacy: "ANIMATE"
#     person: "UNKNOWN"
#     startIndex: 6
#     endIndex: 9
#     headIndex: 8
#     headString: "novia"
#     nerString: "O"
#     originalRef: -1
#     goldCorefClusterID: -1
#     corefClusterID: 2
#     mentionNum: 2
#     sentNum: 0
#     utter: 0
#     paragraph: 1
#     isSubject: false
#     isDirectObject: false
#     isIndirectObject: false
#     isPrepositionObject: false
#     hasTwin: false
#     generic: false
#     isSingleton: false
#     hasBasicDependency: true
#     hasEnhancedDepenedncy: true
#     hasContextParseTree: false
#     headIndexedWord {
#       sentenceNum: -1
#       tokenIndex: 8
#       copyCount: 0
#     }
#     dependingVerb {
#       sentenceNum: -1
#       tokenIndex: 5
#       copyCount: 0
#     }
#     headWord {
#       sentenceNum: -1
#       tokenIndex: 8
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 0
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 1
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 2
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 3
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 4
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 5
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 6
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 7
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 8
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 9
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 10
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 11
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 12
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 13
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 14
#     }
#     sentenceWords {
#       sentenceNum: -1
#       tokenIndex: 15
#     }
#     originalSpan {
#       sentenceNum: -1
#       tokenIndex: 6
#     }
#     originalSpan {
#       sentenceNum: -1
#       tokenIndex: 7
#     }
#     originalSpan {
#       sentenceNum: -1
#       tokenIndex: 8
#     }
#   }
#   hasCorefMentionsAnnotation: true
#   hasEntityMentionsAnnotation: true
# }
# mentions {
#   sentenceIndex: 0
#   tokenStartInSentenceInclusive: 0
#   tokenEndInSentenceExclusive: 1
#   ner: "PERSON"
#   entityType: "PERSON"
#   entityMentionIndex: 0
#   canonicalEntityMentionIndex: 0
#   entityMentionText: "Juan"
# }
# mentions {
#   sentenceIndex: 0
#   tokenStartInSentenceInclusive: 4
#   tokenEndInSentenceExclusive: 5
#   ner: "PERSON"
#   entityType: "PERSON"
#   entityMentionIndex: 1
#   canonicalEntityMentionIndex: 1
#   entityMentionText: "Carla"
# }
# xmlDoc: false
# hasEntityMentionsAnnotation: true
# mentionsForCoref {
#   mentionID: 0
#   mentionType: "PROPER"
#   number: "SINGULAR"
#   gender: "MALE"
#   animacy: "ANIMATE"
#   person: "UNKNOWN"
#   startIndex: 0
#   endIndex: 1
#   headIndex: 0
#   headString: "juan"
#   nerString: "PERSON"
#   originalRef: -1
#   goldCorefClusterID: -1
#   corefClusterID: 0
#   mentionNum: 0
#   sentNum: 0
#   utter: 0
#   paragraph: 1
#   isSubject: true
#   isDirectObject: false
#   isIndirectObject: false
#   isPrepositionObject: false
#   hasTwin: false
#   generic: false
#   isSingleton: false
#   hasBasicDependency: true
#   hasEnhancedDepenedncy: true
#   hasContextParseTree: false
#   headIndexedWord {
#     sentenceNum: -1
#     tokenIndex: 0
#     copyCount: 0
#   }
#   dependingVerb {
#     sentenceNum: -1
#     tokenIndex: 5
#     copyCount: 0
#   }
#   headWord {
#     sentenceNum: -1
#     tokenIndex: 0
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 0
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 1
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 2
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 3
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 4
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 5
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 6
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 7
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 8
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 9
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 10
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 11
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 12
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 13
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 14
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 15
#   }
#   originalSpan {
#     sentenceNum: -1
#     tokenIndex: 0
#   }
# }
# mentionsForCoref {
#   mentionID: 1
#   mentionType: "PROPER"
#   number: "SINGULAR"
#   gender: "FEMALE"
#   animacy: "ANIMATE"
#   person: "UNKNOWN"
#   startIndex: 4
#   endIndex: 5
#   headIndex: 4
#   headString: "carla"
#   nerString: "PERSON"
#   originalRef: -1
#   goldCorefClusterID: -1
#   corefClusterID: 1
#   mentionNum: 1
#   sentNum: 0
#   utter: 0
#   paragraph: 1
#   isSubject: false
#   isDirectObject: false
#   isIndirectObject: false
#   isPrepositionObject: false
#   hasTwin: false
#   generic: false
#   isSingleton: false
#   hasBasicDependency: true
#   hasEnhancedDepenedncy: true
#   hasContextParseTree: false
#   headIndexedWord {
#     sentenceNum: -1
#     tokenIndex: 4
#     copyCount: 0
#   }
#   dependingVerb {
#     sentenceNum: -1
#     tokenIndex: 5
#     copyCount: 0
#   }
#   headWord {
#     sentenceNum: -1
#     tokenIndex: 4
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 0
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 1
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 2
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 3
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 4
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 5
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 6
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 7
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 8
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 9
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 10
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 11
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 12
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 13
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 14
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 15
#   }
#   originalSpan {
#     sentenceNum: -1
#     tokenIndex: 4
#   }
# }
# mentionsForCoref {
#   mentionID: 2
#   mentionType: "NOMINAL"
#   number: "SINGULAR"
#   gender: "MALE"
#   animacy: "ANIMATE"
#   person: "UNKNOWN"
#   startIndex: 6
#   endIndex: 9
#   headIndex: 8
#   headString: "novia"
#   nerString: "O"
#   originalRef: -1
#   goldCorefClusterID: -1
#   corefClusterID: 2
#   mentionNum: 2
#   sentNum: 0
#   utter: 0
#   paragraph: 1
#   isSubject: false
#   isDirectObject: false
#   isIndirectObject: false
#   isPrepositionObject: false
#   hasTwin: false
#   generic: false
#   isSingleton: false
#   hasBasicDependency: true
#   hasEnhancedDepenedncy: true
#   hasContextParseTree: false
#   headIndexedWord {
#     sentenceNum: -1
#     tokenIndex: 8
#     copyCount: 0
#   }
#   dependingVerb {
#     sentenceNum: -1
#     tokenIndex: 5
#     copyCount: 0
#   }
#   headWord {
#     sentenceNum: -1
#     tokenIndex: 8
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 0
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 1
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 2
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 3
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 4
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 5
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 6
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 7
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 8
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 9
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 10
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 11
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 12
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 13
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 14
#   }
#   sentenceWords {
#     sentenceNum: -1
#     tokenIndex: 15
#   }
#   originalSpan {
#     sentenceNum: -1
#     tokenIndex: 6
#   }
#   originalSpan {
#     sentenceNum: -1
#     tokenIndex: 7
#   }
#   originalSpan {
#     sentenceNum: -1
#     tokenIndex: 8
#   }
# }
# hasCorefMentionAnnotation: true
# hasCorefAnnotation: true
# corefMentionToEntityMentionMappings: 0
# corefMentionToEntityMentionMappings: 1
# corefMentionToEntityMentionMappings: -1
# entityMentionToCorefMentionMappings: 0
# entityMentionToCorefMentionMappings: 1

# %% [markdown]
# OK! Looks like the coreference resolution here doesn't really work at all.
